# %%
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt

plt.style.use("seaborn-v0_8-darkgrid")
plt.rcParams["figure.figsize"] = (12, 9)
plt.rcParams["font.family"] = "DejaVu Sans"

from sklearn.metrics import log_loss
from sklearn.cluster import AgglomerativeClustering, KMeans, SpectralClustering
from sklearn.decomposition import PCA
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import StandardScaler

RANDOM_STATE = 42

# %%
PATH = '/Users/nikolaj/Downloads/'

# %%
heart_disease = pd.read_csv(PATH + 'heart_disease.csv', index_col='id')

# %%
heart_disease.head()
# Out:
#     age     sex    dataset  ...        slope   ca               thal
# id                          ...
# 0    63    Male  Cleveland  ...  downsloping  0.0       fixed defect
# 1    67    Male  Cleveland  ...         flat  3.0             normal
# 2    67    Male  Cleveland  ...         flat  2.0  reversable defect
# 3    37    Male  Cleveland  ...  downsloping  0.0             normal
# 4    41  Female  Cleveland  ...    upsloping  0.0             normal
#
# [5 rows x 14 columns]

# %%
sample = pd.read_csv(PATH + 'sample.csv')

# %%
heart_disease.head()
# Out:
#     age     sex    dataset  ...        slope   ca               thal
# id                          ...
# 0    63    Male  Cleveland  ...  downsloping  0.0       fixed defect
# 1    67    Male  Cleveland  ...         flat  3.0             normal
# 2    67    Male  Cleveland  ...         flat  2.0  reversable defect
# 3    37    Male  Cleveland  ...  downsloping  0.0             normal
# 4    41  Female  Cleveland  ...    upsloping  0.0             normal
#
# [5 rows x 14 columns]

# %%
heart_disease.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 920 entries, 0 to 919
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       920 non-null    int64
#  1   sex       920 non-null    object
#  2   dataset   920 non-null    object
#  3   cp        920 non-null    object
#  4   trestbps  920 non-null    float64
#  5   chol      920 non-null    float64
#  6   fbs       920 non-null    object
#  7   restecg   920 non-null    object
#  8   thalch    920 non-null    float64
#  9   exang     920 non-null    object
#  10  oldpeak   920 non-null    float64
#  11  slope     920 non-null    object
#  12  ca        309 non-null    float64
#  13  thal      920 non-null    object
# dtypes: float64(5), int64(1), object(8)
# memory usage: 107.8+ KB

# %% [markdown]
# How to deal with NAs
# trestbps - mean
# chol - mean
# fbs - unknown
# restecg - moda
# thalch - mean
# exang - unknown
# oldpeak - mean
# slope - moda
# ca - unknown
# thal - unknown

# %%
for col in ['trestbps', 'chol', 'thalch', 'oldpeak']:
    heart_disease.fillna({col: heart_disease[col].mean()}, inplace=True)

# %%
for col in ['thal', 'slope', 'exang', 'restecg', 'fbs' ]:
    heart_disease.fillna({col: 'unknown'}, inplace=True)

# %%
hd_no_ca = heart_disease.drop('ca', axis=1)

# %%
scaler = StandardScaler()

# %%
def to_dummy(data):
    obj_type_cols = data.select_dtypes(include=['object'])
    X = pd.get_dummies(obj_type_cols, dtype='int')
    for col in obj_type_cols: 
        n = obj_type_cols[col].nunique() #nr of unique variables in a column
        for c in X.columns:
            if c.startswith(col):
                X[c] = X[c]/n
        #find all columns derived from 'col' and 
        #divide values by a number of derived cols (nr of unique variables) 'n'
        # why i chose this method: https://visualstudiomagazine.com/articles/2024/05/15/clustering-mixed-categorical-and-numeric-data.aspx#:~:text=For%20strictly%20numeric%20data%2C%20the,Bayesian%20probability%20or%20categorical%20utility.
    
   
    return pd.concat([data.select_dtypes(exclude=['object']), X], axis=1)

# %%
X = to_dummy(hd_no_ca)

# %%
X.shape
# Out:
# (920, 33)

# %%
X.head()
# Out:
#     age  trestbps   chol  ...  thal_normal  thal_reversable defect  thal_unknown
# id                        ...
# 0    63     145.0  233.0  ...         0.00                    0.00           0.0
# 1    67     160.0  286.0  ...         0.25                    0.00           0.0
# 2    67     120.0  229.0  ...         0.00                    0.25           0.0
# 3    37     130.0  250.0  ...         0.25                    0.00           0.0
# 4    41     130.0  204.0  ...         0.25                    0.00           0.0
#
# [5 rows x 33 columns]

# %%
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA(0.9, random_state=RANDOM_STATE).fit(X_scaled)

# %%
pca.explained_variance_ratio_.shape[0]
# Out:
# 18

# %%
X_scaled_pca = pca.transform(X_scaled)

# %%
X_scaled_pca.shape
# Out:
# (920, 18)

# %%
for k in range(2, 10):
    kmeans = KMeans(n_clusters=k, random_state=RANDOM_STATE, init='auto', )

# %%
pca2 = PCA(2, random_state=RANDOM_STATE)
X_scaled_pca2 = pca2.fit_transform(X_scaled)

# %%
plt.scatter(X_scaled_pca2[:,0], X_scaled_pca2[:,1])
